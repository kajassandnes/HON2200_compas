# %% [markdown]
# ## HON2200 Project 1 ##
#
# This notebook is one of two notebooks that are containing code and data analysis for the COMPAS-project. The data that is analysed is stored in a csv-file. This notebook is containing the "general analysis" of the data, and are centered about the problems a), c) and d).
#
# ### Problem a)
#
# In the next codeblock I will read the data from the csv-file and print the headers.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# read data from csv-file
data = pd.read_csv('compas-scores-two-years.csv')

heads = data.columns

# printing heads
'''print(heads)'''
# Out:
# 'print(heads)'

# %% [markdown]
# By running the code-block above (remove the apostrophe's around "print") you see a list of all the categories in the dataset. I will now make a new list of headers with the desired, relevant categories. I also want to remove all the cases where there was over 30 days between the arrest and the Compas screening.
#
# *“If the charge date of a defendants Compas scored crime was not within 30 days from when the person was arrested, we assume that because of data quality reasons, that we do not have the right offense.”*
#
# I want to get a overview over the the different "race"-categories.

# %%
# removing defendants that were screened over 30 days after arrest.
data = data[data["days_b_screening_arrest"] <= 30]
data = data[data["days_b_screening_arrest"] >= -30]

# chosing relevant columns
data = data[['sex', 'race', 'decile_score', 'is_recid', 'score_text', "age_cat",
             "priors_count", "c_charge_degree", "two_year_recid"]]

# printing different race-categories
races = data['race'].unique()
for race in races:
    print(race)
# Out:
# Other
# African-American
# Caucasian
# Hispanic
# Asian
# Native American

# %% [markdown]
# ### Time for plots!
#
# #### **How often certain groups of people repeat crimes in the future**
#
# ***Analyse***:
#
# By running the code-block and looking at the plot, we can see that there are significant higher rate of men that reoffend than women, 47% to 35%. There are also about 5 times more men that is arrested as well. This might not come as a shock. When it comes to the "racial" differences between afro-american and caucasian, we see that 52% of the afro-american that are arrested reoffend, while the same number is 39% for caucasian. The difference of 13% is quite noticable. In addition there is approximately 50% more afro-american that are arrested than caucasian.

# %%
# categorizing
men = data[data['sex'] == 'Male']
women = data[data['sex'] == 'Female']
black = data[data['race'] == 'African-American']
white = data[data['race'] == 'Caucasian']

# even more categorizing
categories = {
    'men (r)': [men, men[men['two_year_recid'] == 1]],
    'women (r)': [women, women[women['two_year_recid'] == 1]],
    'afro-american (r)': [black, black[black['two_year_recid'] == 1]],
    'caucasian'
    ' (r)': [white, white[white['two_year_recid'] == 1]],
}

# persentages of reciditive defendants
percentages = []
columns = []
for key, item in categories.items():
    percentages.append((len(item[1]) / len(item[0])) * 100)
    columns.append(key)

# printing percentages
i=0
print("PERCENTAGES OF RESIDIVISM ")
for c in categories.keys():
    print(f"{c}: {percentages[i]:.2f} %")
    i+=1

# printing number of reoffenders
print(f"\nNUMBER OF REOFFENDERS (TOTAL ARRESTS)")
print(f"men: {len(men[men['two_year_recid'] == 1])} (total = {(100*len(men[men['two_year_recid'] == 1]) / percentages[0]):.0f})")
print(f"women: {len(women[women['two_year_recid'] == 1])} (total = {(100*len(women[women['two_year_recid'] == 1]) / percentages[1]):.0f})")
print(f"afro-american: {len(black[black['two_year_recid'] == 1])} (total = {(100*len(black[black['two_year_recid'] == 1]) / percentages[2]):.0f})")
print(f"caucasian: {len(white[white['two_year_recid'] == 1])} (total = {(100*len(white[white['two_year_recid'] == 1]) / percentages[3]):.0f})")

# Plotting bars
plt.bar(columns, percentages)
plt.ylabel('Percentage [%]', fontsize = 14)      
plt.legend(['r - recidivism'])
plt.title('Percentage of the Group That Reoffended')
plt.grid()
plt.show()
# Out:
# PERCENTAGES OF RESIDIVISM
# men (r): 47.95 %
# women (r): 35.15 %
# afro-american (r): 52.31 %
# caucasian (r): 39.09 %
#
# NUMBER OF REOFFENDERS (TOTAL ARRESTS)
# men: 2396 (total = 4997)
# women: 413 (total = 1175)
# afro-american: 1661 (total = 3175)
# caucasian: 822 (total = 2103)

# %% [markdown]
# #### **How often certain groups of people is predicted by the algorithm to commit new crimes in the future**
#
# ***Analyse:***
#
# From looking at the bar-plot, if we assume that everyone that is flagged as 'medium' and 'high' risk commit a new crime in the future, we can see that the overall prediction agrees well with the actual percentages of reoffenders. From the bar-plot, nearly 50% afro-american and a bit over 40% caucasian is predicted to reoffend.

# %%
risks = ['Low', 'Medium', 'High']
numbers_men = []

categories = {
    'men_low': [men, men[men['score_text'] == 'Low']],
    'men_medium': [men, men[men['score_text'] == 'Medium']],
    'men_high': [men, men[men['score_text'] == 'High']],
    'women_low': [women, women[women['score_text'] == 'Low']],
    'women_medium': [women, women[women['score_text'] == 'Medium']],
    'women_high': [women, women[women['score_text'] == 'High']],
    'black_low': [black, black[black['score_text'] == 'Low']],
    'black_medium': [black, black[black['score_text'] == 'Medium']],
    'black_high': [black, black[black['score_text'] == 'High']],
    'white_low': [white, white[white['score_text'] == 'Low']],
    'white_medium': [white, white[white['score_text'] == 'Medium']],
    'white_high': [men, men[men['score_text'] == 'High']]
}


percentages = []
columns = ['Low', 'Medium', 'High']
for key, item in categories.items():
    percentages.append((len(item[1]) / len(item[0])) * 100)

men_p = percentages[0:3]
women_p = percentages[3:6]
black_p = percentages[6:9]
white_p = percentages[9:12]

x = np.arange(len(columns))
width = 0.2

fig, ax = plt.subplots()
ax.bar(x - 1.5*width, men_p, width, label='Men')
ax.bar(x - 0.5*width, women_p, width, label='Women')
ax.bar(x + 0.5*width, black_p, width, label='Afro-american')
ax.bar(x + 1.5*width, white_p, width, label='Caucasian')

ax.set_ylabel('Percentage [%]', fontsize = 14)     
ax.legend()
ax.set_xticks(x)
ax.set_xticklabels(columns)
ax.set_title('Percentage of Group That is Predicted to Risk Scores')
plt.tight_layout()
plt.grid()
plt.show()

print("Total percent that were flagged medium + high")
print(f'Men: {(men_p[1] + men_p[2]):.2f} %')
print(f'Women: {(women_p[1] + women_p[2]):.2f} %')
print(f'Afro-americans: {(black_p[1] + black_p[2]):.2f} %')
print(f'Caucasian: {(white_p[1] + white_p[2]):.2f} %')
# Out:
# Total percent that were flagged medium + high
# Men: 45.53 %
# Women: 40.51 %
# Afro-americans: 57.61 %
# Caucasian: 42.36 %

# %% [markdown]
# #### **How often certain groups of people gained different risk scores**
#
# ***Analyse:***
#
# From the bar-plot we see a big difference in the distributions of risk scores for afro-american and caucasian. While caucasian defendants have a big overweigh at the lowest risk score, and gradually fewer at the higher risk scores, the afro-american defendants are more evenly distributed over all the risk-scores, and a lot more distributed on the higher risk scores.
#
# The fascinating is that the overall label-perdiction into "low". "medium" and "high" seem to agree well with the data. A conclusion coud be that the algorithm catches the big patterns, so that the overall outcome fit well with data, but that the prediction on individual level is biased.

# %%
scores = np.arange(1, 11)
white_counts = []
black_counts = []
for score in scores:
    count_white = white[white['decile_score'] == score]
    count_black = black[black['decile_score'] == score]

    white_counts.append(len(count_white))
    black_counts.append(len(count_black))

fig, axs = plt.subplots(1, 2, sharey = True)
plt.subplot(1, 2, 1)
axs[0].bar(scores, white_counts)
axs[0].set_title("Caucasian Defendant's")
axs[0].set_xlabel('Decile Score', fontsize = 14)
axs[0].set_ylabel('Count', fontsize = 14)

plt.subplot(1, 2, 2)
axs[1].bar(scores, black_counts)
axs[1].set_title("Afro-american Defendant's")
axs[1].set_xlabel('Decile Score', fontsize = 14)
plt.show()

# %% [markdown]
# #### **How often people who commited new crimes was flagged the different risc scores (and those who did not).**
#
# ***Analyse:***
#
# The model seems to be bad at predicting if a defendant is going to reoffend, because the decile score distribution for those who reoffended is almost constant. The defendants that did not reoffend has an overwigh of low decile score.

# %%
# categorizing
r = data[data['two_year_recid'] == 1]
nr = data[data['two_year_recid'] == 0]
wr = white[white['two_year_recid'] == 1]
br = black[black['two_year_recid'] == 1]
wnr = white[white['two_year_recid'] == 0]
bnr = black[black['two_year_recid'] == 0]

scores = np.arange(1, 11)
reoffenders = []
non_reoffenders = []
w_reoffenders = []
b_reoffenders = []
wn_reoffenders = []
bn_reoffenders = []

for score in scores:
    count_r = r[r['decile_score'] == score]
    count_nr = nr[nr['decile_score'] == score]
    count_wr = wr[wr['decile_score'] == score]
    count_br = br[br['decile_score'] == score]
    count_wnr = wnr[wnr['decile_score'] == score]
    count_bnr = bnr[bnr['decile_score'] == score]


    reoffenders.append(len(count_r))
    non_reoffenders.append(len(count_nr))
    w_reoffenders.append(len(count_wr))
    b_reoffenders.append(len(count_br))
    wn_reoffenders.append(len(count_wnr))
    bn_reoffenders.append(len(count_bnr))


fig, axs = plt.subplots(1, 2, sharey = True)
# 6 plots
plt.subplot(1, 2, 1)
axs[0].bar(scores, reoffenders)
axs[0].set_title('Reoffenders')
axs[0].set_xlabel('Decile Score', fontsize = 14)
axs[0].set_ylabel('Count', fontsize = 14)

plt.subplot(1, 2, 2)
axs[1].bar(scores, non_reoffenders)
axs[1].set_title('Non-Reoffenders')
axs[1].set_xlabel('Decile Score', fontsize = 14)
plt.show()

fig, axs = plt.subplots(1, 2, sharey = True)
plt.subplot(1, 2, 1)
axs[0].bar(scores, w_reoffenders)
axs[0].set_title('Caucasian Reoffenders', fontsize=12)
axs[0].set_xlabel('Decile Score', fontsize = 14)
axs[0].set_ylabel('Count', fontsize = 14)

plt.subplot(1, 2, 2)
axs[1].bar(scores, b_reoffenders)
axs[1].set_title('Afro-american Reoffenders', fontsize=12)
axs[1].set_xlabel('Decile Score', fontsize = 14)
plt.show()

fig, axs = plt.subplots(1, 2, sharey = True)
plt.subplot(1, 2, 1)
axs[0].bar(scores, wn_reoffenders)
axs[0].set_title('Caucasian Non-Reoffenders', fontsize=12)
axs[0].set_xlabel('Decile Score', fontsize = 14)
axs[0].set_ylabel('Count', fontsize = 14)

plt.subplot(1, 2, 2)
axs[1].bar(scores, bn_reoffenders)
axs[1].set_title('Afro-american Non-Reoffenders', fontsize=12)
axs[1].set_xlabel('Decile Score', fontsize = 14)
plt.show()

# %% [markdown]
# I will do the same plot for afro-american and caucasian using percentages instead of count so that they can be comparred.

# %%
w_reoffenders_p = np.array(w_reoffenders) * 100 / len(wr)
b_reoffenders_p = np.array(b_reoffenders) * 100 / len(br)
wn_reoffenders_p = np.array(wn_reoffenders) * 100 / len(wnr)
bn_reoffenders_p = np.array(bn_reoffenders) * 100 / len(bnr)

fig, axs = plt.subplots(1, 2, sharey = True)
plt.subplot(1, 2, 1)
axs[0].bar(scores, w_reoffenders_p)
axs[0].set_title('Caucasian Reoffenders')
axs[0].set_xlabel('Decile Score', fontsize = 14)
axs[0].set_ylabel('Percentage [%]', fontsize = 14)

plt.subplot(1, 2, 2)
axs[1].bar(scores, b_reoffenders_p)
axs[1].set_title('Afro-american Reoffenders')
axs[1].set_xlabel('Decile Score', fontsize = 14)
plt.show()

fig, axs = plt.subplots(1, 2, sharey = True)
plt.subplot(1, 2, 1)
axs[0].bar(scores, wn_reoffenders_p)
axs[0].set_title('Caucasian Non-Reoffenders')
axs[0].set_xlabel('Decile Score', fontsize = 14)
axs[0].set_ylabel('Percentage [%]', fontsize = 14)

plt.subplot(1, 2, 2)
axs[1].bar(scores, bn_reoffenders_p)
axs[1].set_title('Afroamerican Non-Reoffenders')
axs[1].set_xlabel('Decile Score', fontsize = 14)
plt.show()

# %% [markdown]
# I want to look at the probability to reoffend if a defendant is rated a specific decile score.

# %%
probability_r = []
probability_wr = []
probability_br = []

for score in scores:
    cr = len(r[r['decile_score'] == score]) # number of reoffending defendants that got the decile score 'score'
    cnr = len(nr[nr['decile_score'] == score]) # number of non-reoffending defendants that got the decile score 'score'
    total_score = cr + cnr
    probability_r.append(cr * 100 / total_score)

    cwr = len(wr[wr['decile_score'] == score]) # number of reoffending defendants that got the decile score 'score'
    cwnr = len(wnr[wnr['decile_score'] == score]) # number of non-reoffending defendants that got the decile score 'score'
    total_score = cwr + cwnr
    probability_wr.append(cwr * 100 / total_score)

    cbr = len(br[br['decile_score'] == score]) # number of reoffending defendants that got the decile score 'score'
    cbnr = len(bnr[bnr['decile_score'] == score]) # number of non-reoffending defendants that got the decile score 'score'
    total_score = cbr + cbnr
    probability_br.append(cbr * 100 / total_score)

plt.plot(scores, probability_r, label='All')
plt.plot(scores, probability_br, label='Afro-american', color='green')
plt.plot(scores, probability_wr, label='Caucasian', color='red')
plt.title('Probability to Reoffend Given Score', fontsize = 14)
plt.xlabel('Decile Score', fontsize = 14)
plt.ylabel('Probability [%]', fontsize = 14)
plt.legend()
plt.show()

# %% [markdown]
# ### Problem c)
#
# It is a connection between the presicion to the COMPAS algorithm and the degree of discrimination it imposes different groups of people.
#
# When the COMPAS-algorithm is predicting the risk-scores, it uses 'race' as a parameter. Bayes' sentence says:
#
# >>>>>>>>>>>>>>>>> #### $P(R|G) = \frac{P(G|R) P(R)}{P(G)}$
#
# So the algorithm find the probability of reoffend ($R$) given race ($G$) by looking at the probability that the defendant is a specific race given that they reoffended, the total probability of reoffending and the total probability of being that specific race.
#
# When the COMPAS-algorithm predicts the decile-score of a defendant, it takes into account the probability of reoffending given their race, by using previous data.
#
# If we look at earlier data of defendants that reoffend, and there is an overweight of a specific race within those data, the algorithm will predict a higher risc score given that race.
#
# Therefore, biased data lead to biased predictions.

# %% [markdown]
# ### Problem d)

# %% [markdown]
# I want to see if there are "race" bias in the algorithm, by changing only this variable, while holding the other ones constant. I do this by making a model and by training it on test-data.
#
# My baseline defendant is between 25 and 45 in age, Caucasian, male with 0 prior crimes that has done a felony crime.
#
# ***Analyse:***
#
# The accuracy of my model is 0.74. The racial bias is around 1.5, which means that afro-americans has a 50 percent higher probability to be predicted to commit a future crime.

# %%
import sklearn as skl

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

X = data[["age_cat", "race", "sex", "priors_count", "c_charge_degree", "two_year_recid"]]

# doing one-hot encoding
categorical_cols = ["age_cat", "race", "sex", "c_charge_degree"]
X = pd.get_dummies(X, columns=categorical_cols, prefix=categorical_cols, prefix_sep='_')

# Avoiding dummy variable trap (removing columns that has a reference column)
X = X.drop(["age_cat_25 - 45", "race_Caucasian", "sex_Male", "c_charge_degree_F"], axis=1)

# This is what the model want to predict
Y = data["score_text"] != "Low"


# splitter opp i treningsdata og testdata
X_train, X_test, Y_train, Y_test = skl.model_selection.train_test_split(X, Y)

X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_test = np.array(X_test)
Y_test = np.array(Y_test)

# make the model
model = skl.linear_model.LogisticRegression()

# train the model
model.fit(X_train, Y_train)

# prediction
y_pred = model.predict(X_test)

# Accuracy
accuracy = skl.metrics.accuracy_score(Y_test, y_pred)

print(f"Accuracy: {accuracy:.5f}")

b = model.intercept_[0]
feature_names = X.columns
coefs = dict(zip(feature_names, model.coef_[0]))

'''print(coefs)'''
w_african_american = coefs["race_African-American"]
'''print(f"Weight african-american: {w_african_american}")
print(f"b: {b}")'''

control = sigmoid(b)
print(f"Baseline probability: {control}")
w_r = coefs["race_African-American"]
e_am = np.exp(coefs["race_African-American"])
racialBias = e_am  / (1 - control + (control * e_am))
print(f"Racial Bias: {racialBias}")

effect = racialBias - control

print(f"Effect: {effect}")
# Out:
# Accuracy: 0.74530
# Baseline probability: 0.17030745446868806
# Racial Bias: 1.5499639146859143
# Effect: 1.3796564602172263
